# %% [markdown]
# **Team NPCs**
#
# Axel Petit/ 2023848335 / axelpetit375@gmail.com
#
# Isabel Vieyra / 2023849316 / a01745860@tec.mx
#
# Kian Horsmeier / 202384645 / kianwhorsmeier@gmail.com
#
# Santiago Pérez / 2023849312/ SantiagoPerezEsc@gmail.com
#
# Mona Lin / 2023849096 / monalin2002@gmail.com

# %% [markdown]
# **Dataset**
# https://data.cityofchicago.org/Transportation/Traffic-Crashes-Crashes/85ca-t3if/explore

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("85ca-t3if", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df.columns
# Out:
# Index(['crash_record_id', 'crash_date', 'posted_speed_limit',
#        'traffic_control_device', 'device_condition', 'weather_condition',
#        'lighting_condition', 'first_crash_type', 'trafficway_type',
#        'alignment', 'roadway_surface_cond', 'road_defect', 'report_type',
#        'crash_type', 'damage', 'date_police_notified',
#        'prim_contributory_cause', 'sec_contributory_cause', 'street_no',
#        'street_direction', 'street_name', 'beat_of_occurrence', 'num_units',
#        'most_severe_injury', 'injuries_total', 'injuries_fatal',
#        'injuries_incapacitating', 'injuries_non_incapacitating',
#        'injuries_reported_not_evident', 'injuries_no_indication',
#        'injuries_unknown', 'crash_hour', 'crash_day_of_week', 'crash_month',
#        'latitude', 'longitude', 'location', ':@computed_region_rpca_8um6',
#        'hit_and_run_i', 'crash_date_est_i', 'intersection_related_i',
#        'private_property_i', 'photos_taken_i', 'statements_taken_i',
#        'work_zone_i', 'work_zone_type', 'dooring_i', 'workers_present_i'],
#       dtype='object')

# %%
results_df.head(6)
# Out:
#                                      crash_record_id               crash_date  \
# 0  bc3c61d5dbe43abd180a650279a7623d9ecda1a520d8ff...  2023-11-09T02:40:00.000
# 1  93178a4bc7997b3ef129dff65a54c3d3892a15155c05f9...  2023-11-09T02:30:00.000
# 2  ed4ce4638847ebd835a2f72e1353938b431ecfc5e1ba26...  2023-11-09T02:20:00.000
# 3  14aa2b51698d4beb63e4ed4af6844dd0bd773c6d823a11...  2023-11-09T01:10:00.000
# 4  17aed734136c8c016fad96ae424f28ce816a9430ced03f...  2023-11-08T23:10:00.000
# 5  1654260fb034c1cc92df9c1ba6ab1ccf555de9e105a05e...  2023-11-08T22:50:00.000
#
#   posted_speed_limit traffic_control_device      device_condition  \
# 0                 30            NO CONTROLS           NO CONTROLS
# 1                 30            NO CONTROLS           NO CONTROLS
# 2                 30            NO CONTROLS           NO CONTROLS
# 3                 35            NO CONTROLS           NO CONTROLS
# 4                 30         TRAFFIC SIGNAL  FUNCTIONING PROPERLY
# 5                 30      STOP SIGN/FLASHER  FUNCTIONING PROPERLY
#
#   weather_condition      lighting_condition      first_crash_type  \
# 0             CLEAR  DARKNESS, LIGHTED ROAD          FIXED OBJECT
# 1             CLEAR  DARKNESS, LIGHTED ROAD  PARKED MOTOR VEHICLE
# 2             CLEAR  DARKNESS, LIGHTED ROAD               TURNING
# 3             CLEAR  DARKNESS, LIGHTED ROAD  PARKED MOTOR VEHICLE
# 4             CLEAR  DARKNESS, LIGHTED ROAD                 ANGLE
# 5             CLEAR  DARKNESS, LIGHTED ROAD                 ANGLE
#
#   trafficway_type           alignment  ... hit_and_run_i crash_date_est_i  \
# 0     NOT DIVIDED  STRAIGHT AND LEVEL  ...           NaN              NaN
# 1         ONE-WAY  STRAIGHT AND LEVEL  ...             Y              NaN
# 2         ONE-WAY  STRAIGHT AND LEVEL  ...           NaN              NaN
# 3     NOT DIVIDED  STRAIGHT AND LEVEL  ...             Y                Y
# 4        FOUR WAY  STRAIGHT AND LEVEL  ...           NaN              NaN
# 5        FOUR WAY  STRAIGHT AND LEVEL  ...           NaN              NaN
#
#   intersection_related_i private_property_i photos_taken_i statements_taken_i  \
# 0                    NaN                NaN            NaN                NaN
# 1                    NaN                NaN            NaN                NaN
# 2                    NaN                NaN            NaN                NaN
# 3                    NaN                NaN            NaN                NaN
# 4                      Y                NaN            NaN                NaN
# 5                      Y                NaN            NaN                NaN
#
#   work_zone_i work_zone_type dooring_i workers_present_i
# 0         NaN            NaN       NaN               NaN
# 1         NaN            NaN       NaN               NaN
# 2         NaN            NaN       NaN               NaN
# 3         NaN            NaN       NaN               NaN
# 4         NaN            NaN       NaN               NaN
# 5         NaN            NaN       NaN               NaN
#
# [6 rows x 48 columns]
